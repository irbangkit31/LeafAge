# %% [markdown]
# ## **Capstone Project of Bangkit**
#
# Team C23-PC767

# %%
# The first thing to do is to import libraries

import os
import zipfile
import random
import shutil
import pandas as pd
import string
import numpy as np
from shutil import copyfile

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img
from keras.models import Sequential
from keras.layers import Dense

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# This code aims to import the file from /content/Monkey Pod Tree Dataset with the format of the file is excel
# The excel has been uploaded to this google colab workbook
file_path = "/content/Full Dataset.xlsx"

# This code aims to read the Excel file into a pandas DataFrame
df = pd.read_excel(file_path)

# %%
column_names = df.columns.tolist()
if 'heights' not in column_names or 'circumferences' not in column_names or 'ages' not in column_names:
    raise ValueError("Column names not found in the dataset.")

dataset_array = df.values

X = dataset_array[:, [column_names.index('heights'), column_names.index('circumferences')]]
y = dataset_array[:, column_names.index('ages')]

# %%
# In this block of code, the dataset will be converted to a numpy array

data = df.to_numpy()
print("Shape of the data array:", data.shape)
# Out:
# Shape of the data array: (358, 5)

# %%
#This code aims to generate the output of the dataset from the head 20  rows
data.head(5)
# Out:
#    heights  circumferences  ages    ratios  status
# 0       10               7    23  0.700000       1
# 1       10               7    23  0.700000       1
# 2       10               8    22  0.800000       1
# 3       10               8    25  0.800000       1
# 4       17              14    35  0.823529       1

# %%
#This code aims to generate the output of the dataset from the head 20  rows
data.tail(5)
# Out:
#      heights  circumferences  ages  ratios  status
# 353        6              30    20     5.0       0
# 354        5              26    23     5.2       0
# 355        5              27    23     5.4       0
# 356        5              29    23     5.8       0
# 357        5              30    22     6.0       0

# %%
# This block of code aims to normalize the data using StandardScaler

def normalize_data(df):
    heights = df['heights']
    circumferences = df['circumferences']
    ages = df['ages']

    scaler = StandardScaler()
    X = df[['heights', 'circumferences']]
    X_normalized = scaler.fit_transform(X)

    normalized_heights = X_normalized[:, 0]
    normalized_circumferences = X_normalized[:, 1]

    return normalized_heights, normalized_circumferences, scaler

# %%
# In this code, the data will be splitted

def split_dataset(df, test_size, dev_size):
    X = df[['heights', 'circumferences']]
    y = df['ages']

    # Process of spliting the dataset into train and test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

    # Process of spliting the dataset into dev and test
    X_dev, X_test, y_dev, y_test = train_test_split(X_test, y_test, test_size=dev_size, random_state=42)

    return X_train, X_test, X_dev, y_train, y_test, y_dev

# Then, call the function with our DataFrame and sizes for test and dev
test_size = 0.2
dev_size = 0.25 
X_train, X_test, X_dev, y_train, y_test, y_dev = split_dataset(df, test_size, dev_size)

# Last, print the shapes of the split datasets
print("Train set shapes:")
print(X_train.shape, y_train.shape)
print("Validation set shapes:")
print(X_dev.shape, y_dev.shape)
print("Test set shapes:")
print(X_test.shape, y_test.shape)
# Out:
# Train set shapes:
# (286, 2) (286,)
# Validation set shapes:
# (54, 2) (54,)
# Test set shapes:
# (18, 2) (18,)

# %%
# In this code, the model will be trained

def train_neural_network(X_train, y_train, X_val, y_val):
    # Scale the features using StandardScaler
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)

    # Then, create a neural network model using keras.layers
    model = keras.Sequential([
        keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dense(1)
    ])

    # Then, compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train the model
    history = model.fit(X_train_scaled, y_train, epochs=200, batch_size=32, validation_data=(X_val_scaled, y_val))

    model.save('LeafAge.h5')
    model.save_weights("LeafAge.weights.bin")


    return model, history

# Data preparation
X_train, X_test, X_dev, y_train, y_test, y_dev = split_dataset(df, test_size, dev_size)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_dev_scaled = scaler.transform(X_dev)

# Then, train the neural network
trained_model, history = train_neural_network(X_train_scaled, y_train, X_dev_scaled, y_dev)

# Then, evaluate the model on the test set
X_test_scaled = scaler.transform(X_test)
test_loss = trained_model.evaluate(X_test_scaled, y_test)
print("Test Loss:", test_loss)

# Make predictions on the test set
y_pred = trained_model.predict(X_test_scaled)

# Last, plot the loss curves
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 9/9 [==============================] - 1s 27ms/step - loss: 2007.1486 - val_loss: 1901.6954
# Epoch 2/200
# 9/9 [==============================] - 0s 5ms/step - loss: 1973.9222 - val_loss: 1867.9919
# Epoch 3/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1937.2458 - val_loss: 1828.5547
# Epoch 4/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1890.8328 - val_loss: 1777.4768
# Epoch 5/200
# 9/9 [==============================] - 0s 9ms/step - loss: 1829.7179 - val_loss: 1709.8267
# Epoch 6/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1751.5558 - val_loss: 1622.4091
# Epoch 7/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1651.5204 - val_loss: 1514.2289
# Epoch 8/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1528.0308 - val_loss: 1384.6071
# Epoch 9/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1380.6626 - val_loss: 1233.9985
# Epoch 10/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1217.1735 - val_loss: 1062.0558
# Epoch 11/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1033.9745 - val_loss: 878.1953
# Epoch 12/200
# 9/9 [==============================] - 0s 8ms/step - loss: 838.7169 - val_loss: 692.6347
# Epoch 13/200
# 9/9 [==============================] - 0s 7ms/step - loss: 647.1420 - val_loss: 516.5278
# Epoch 14/200
# 9/9 [==============================] - 0s 8ms/step - loss: 471.4477 - val_loss: 363.5548
# Epoch 15/200
# 9/9 [==============================] - 0s 6ms/step - loss: 326.9054 - val_loss: 244.3510
# Epoch 16/200
# 9/9 [==============================] - 0s 6ms/step - loss: 221.7642 - val_loss: 163.7160
# Epoch 17/200
# 9/9 [==============================] - 0s 6ms/step - loss: 152.7738 - val_loss: 119.3782
# Epoch 18/200
# 9/9 [==============================] - 0s 6ms/step - loss: 117.7905 - val_loss: 97.8499
# Epoch 19/200
# 9/9 [==============================] - 0s 8ms/step - loss: 102.5351 - val_loss: 87.5948
# Epoch 20/200
# 9/9 [==============================] - 0s 6ms/step - loss: 94.4405 - val_loss: 81.4258
# Epoch 21/200
# 9/9 [==============================] - 0s 8ms/step - loss: 88.2668 - val_loss: 75.7369
# Epoch 22/200
# 9/9 [==============================] - 0s 8ms/step - loss: 82.9217 - val_loss: 70.9283
# Epoch 23/200
# 9/9 [==============================] - 0s 8ms/step - loss: 77.9232 - val_loss: 66.3096
# Epoch 24/200
# 9/9 [==============================] - 0s 9ms/step - loss: 73.1075 - val_loss: 62.8315
# Epoch 25/200
# 9/9 [==============================] - 0s 10ms/step - loss: 68.9546 - val_loss: 58.6905
# Epoch 26/200
# 9/9 [==============================] - 0s 11ms/step - loss: 64.6899 - val_loss: 55.2156
# Epoch 27/200
# 9/9 [==============================] - 0s 9ms/step - loss: 60.9004 - val_loss: 51.8676
# Epoch 28/200
# 9/9 [==============================] - 0s 10ms/step - loss: 57.2908 - val_loss: 48.7347
# Epoch 29/200
# 9/9 [==============================] - 0s 8ms/step - loss: 53.7527 - val_loss: 46.2607
# Epoch 30/200
# 9/9 [==============================] - 0s 8ms/step - loss: 50.6677 - val_loss: 43.6226
# Epoch 31/200
# 9/9 [==============================] - 0s 8ms/step - loss: 47.5847 - val_loss: 40.8736
# Epoch 32/200
# 9/9 [==============================] - 0s 8ms/step - loss: 44.6805 - val_loss: 38.5776
# Epoch 33/200
# 9/9 [==============================] - 0s 11ms/step - loss: 42.1233 - val_loss: 36.3427
# Epoch 34/200
# 9/9 [==============================] - 0s 9ms/step - loss: 39.5758 - val_loss: 34.5883
# Epoch 35/200
# 9/9 [==============================] - 0s 11ms/step - loss: 37.2967 - val_loss: 32.6385
# Epoch 36/200
# 9/9 [==============================] - 0s 11ms/step - loss: 35.1983 - val_loss: 30.6934
# Epoch 37/200
# 9/9 [==============================] - 0s 9ms/step - loss: 33.1745 - val_loss: 29.3487
# Epoch 38/200
# 9/9 [==============================] - 0s 9ms/step - loss: 31.3262 - val_loss: 27.9088
# Epoch 39/200
# 9/9 [==============================] - 0s 8ms/step - loss: 29.6364 - val_loss: 26.5024
# Epoch 40/200
# 9/9 [==============================] - 0s 11ms/step - loss: 28.0014 - val_loss: 25.2010
# Epoch 41/200
# 9/9 [==============================] - 0s 8ms/step - loss: 26.5612 - val_loss: 23.9108
# Epoch 42/200
# 9/9 [==============================] - 0s 10ms/step - loss: 25.1580 - val_loss: 22.7977
# Epoch 43/200
# 9/9 [==============================] - 0s 8ms/step - loss: 23.8223 - val_loss: 21.8368
# Epoch 44/200
# 9/9 [==============================] - 0s 9ms/step - loss: 22.5865 - val_loss: 20.8788
# Epoch 45/200
# 9/9 [==============================] - 0s 8ms/step - loss: 21.5453 - val_loss: 20.0641
# Epoch 46/200
# 9/9 [==============================] - 0s 8ms/step - loss: 20.4310 - val_loss: 19.1607
# Epoch 47/200
# 9/9 [==============================] - 0s 8ms/step - loss: 19.4839 - val_loss: 18.2913
# Epoch 48/200
# 9/9 [==============================] - 0s 8ms/step - loss: 18.5946 - val_loss: 17.6710
# Epoch 49/200
# 9/9 [==============================] - 0s 9ms/step - loss: 17.7656 - val_loss: 17.0590
# Epoch 50/200
# 9/9 [==============================] - 0s 11ms/step - loss: 17.0311 - val_loss: 16.5689
# Epoch 51/200
# 9/9 [==============================] - 0s 11ms/step - loss: 16.3282 - val_loss: 16.0102
# Epoch 52/200
# 9/9 [==============================] - 0s 11ms/step - loss: 15.6558 - val_loss: 15.5079
# Epoch 53/200
# 9/9 [==============================] - 0s 9ms/step - loss: 15.0547 - val_loss: 15.1129
# Epoch 54/200
# 9/9 [==============================] - 0s 10ms/step - loss: 14.5515 - val_loss: 14.7570
# Epoch 55/200
# 9/9 [==============================] - 0s 11ms/step - loss: 14.0175 - val_loss: 14.3137
# Epoch 56/200
# 9/9 [==============================] - 0s 10ms/step - loss: 13.5420 - val_loss: 13.9620
# Epoch 57/200
# 9/9 [==============================] - 0s 6ms/step - loss: 13.1940 - val_loss: 13.8517
# Epoch 58/200
# 9/9 [==============================] - 0s 8ms/step - loss: 12.7147 - val_loss: 13.4903
# Epoch 59/200
# 9/9 [==============================] - 0s 6ms/step - loss: 12.4028 - val_loss: 13.1636
# Epoch 60/200
# 9/9 [==============================] - 0s 6ms/step - loss: 12.0322 - val_loss: 12.9882
# Epoch 61/200
# 9/9 [==============================] - 0s 6ms/step - loss: 11.7365 - val_loss: 12.9295
# Epoch 62/200
# 9/9 [==============================] - 0s 6ms/step - loss: 11.4693 - val_loss: 12.8045
# Epoch 63/200
# 9/9 [==============================] - 0s 6ms/step - loss: 11.2167 - val_loss: 12.5392
# Epoch 64/200
# 9/9 [==============================] - 0s 6ms/step - loss: 10.9797 - val_loss: 12.3856
# Epoch 65/200
# 9/9 [==============================] - 0s 6ms/step - loss: 10.7932 - val_loss: 12.2299
# Epoch 66/200
# 9/9 [==============================] - 0s 6ms/step - loss: 10.5976 - val_loss: 12.3527
# Epoch 67/200
# 9/9 [==============================] - 0s 6ms/step - loss: 10.4115 - val_loss: 12.1248
# Epoch 68/200
# 9/9 [==============================] - 0s 8ms/step - loss: 10.2676 - val_loss: 11.9882
# Epoch 69/200
# 9/9 [==============================] - 0s 9ms/step - loss: 10.0601 - val_loss: 11.9572
# Epoch 70/200
# 9/9 [==============================] - 0s 8ms/step - loss: 9.9756 - val_loss: 12.0890
# Epoch 71/200
# 9/9 [==============================] - 0s 6ms/step - loss: 9.8046 - val_loss: 11.9505
# Epoch 72/200
# 9/9 [==============================] - 0s 8ms/step - loss: 9.6600 - val_loss: 11.8638
# Epoch 73/200
# 9/9 [==============================] - 0s 7ms/step - loss: 9.5719 - val_loss: 11.6670
# Epoch 74/200
# 9/9 [==============================] - 0s 6ms/step - loss: 9.4535 - val_loss: 11.6981
# Epoch 75/200
# 9/9 [==============================] - 0s 8ms/step - loss: 9.3529 - val_loss: 11.8658
# Epoch 76/200
# 9/9 [==============================] - 0s 6ms/step - loss: 9.3126 - val_loss: 11.9625
# Epoch 77/200
# 9/9 [==============================] - 0s 6ms/step - loss: 9.1936 - val_loss: 11.8075
# Epoch 78/200
# 9/9 [==============================] - 0s 8ms/step - loss: 9.1292 - val_loss: 11.7638
# Epoch 79/200
# 9/9 [==============================] - 0s 6ms/step - loss: 9.1093 - val_loss: 11.8150
# Epoch 80/200
# 9/9 [==============================] - 0s 7ms/step - loss: 9.0244 - val_loss: 11.7887
# Epoch 81/200
# 9/9 [==============================] - 0s 6ms/step - loss: 9.0093 - val_loss: 11.6963
# Epoch 82/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.9309 - val_loss: 11.8185
# Epoch 83/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.9441 - val_loss: 11.9680
# Epoch 84/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.8671 - val_loss: 11.8905
# Epoch 85/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.8321 - val_loss: 11.7899
# Epoch 86/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.8069 - val_loss: 11.8026
# Epoch 87/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.7551 - val_loss: 11.8416
# Epoch 88/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.7793 - val_loss: 11.8845
# Epoch 89/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.7512 - val_loss: 11.8329
# Epoch 90/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.7108 - val_loss: 11.8853
# Epoch 91/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.6896 - val_loss: 11.9910
# Epoch 92/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.6581 - val_loss: 11.9579
# Epoch 93/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.6276 - val_loss: 11.8496
# Epoch 94/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.6370 - val_loss: 11.9677
# Epoch 95/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.6128 - val_loss: 11.8931
# Epoch 96/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.5959 - val_loss: 12.0153
# Epoch 97/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.6271 - val_loss: 11.8083
# Epoch 98/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.5524 - val_loss: 11.9867
# Epoch 99/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.5894 - val_loss: 12.1307
# Epoch 100/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.5842 - val_loss: 11.9014
# Epoch 101/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.5314 - val_loss: 11.8957
# Epoch 102/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.5422 - val_loss: 11.9905
# Epoch 103/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.5049 - val_loss: 12.0093
# Epoch 104/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.4878 - val_loss: 11.8647
# Epoch 105/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.4650 - val_loss: 11.9682
# Epoch 106/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.4948 - val_loss: 12.0637
# Epoch 107/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.4385 - val_loss: 12.0552
# Epoch 108/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.4317 - val_loss: 11.9520
# Epoch 109/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.4745 - val_loss: 11.8774
# Epoch 110/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.4130 - val_loss: 12.0121
# Epoch 111/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.4141 - val_loss: 12.0867
# Epoch 112/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.4120 - val_loss: 11.9923
# Epoch 113/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.3844 - val_loss: 11.9572
# Epoch 114/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.4074 - val_loss: 12.1506
# Epoch 115/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.3733 - val_loss: 11.9267
# Epoch 116/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3956 - val_loss: 12.0089
# Epoch 117/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.3977 - val_loss: 11.8245
# Epoch 118/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.3582 - val_loss: 12.0960
# Epoch 119/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3580 - val_loss: 12.0515
# Epoch 120/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3511 - val_loss: 11.9234
# Epoch 121/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.3631 - val_loss: 11.9305
# Epoch 122/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3448 - val_loss: 12.1579
# Epoch 123/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3509 - val_loss: 11.8604
# Epoch 124/200
# 9/9 [==============================] - 0s 32ms/step - loss: 8.3173 - val_loss: 12.0078
# Epoch 125/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.3213 - val_loss: 11.9350
# Epoch 126/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3317 - val_loss: 11.8453
# Epoch 127/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3021 - val_loss: 11.9580
# Epoch 128/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3091 - val_loss: 12.1698
# Epoch 129/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.3200 - val_loss: 11.9124
# Epoch 130/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2924 - val_loss: 11.9399
# Epoch 131/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.2911 - val_loss: 11.8443
# Epoch 132/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.3278 - val_loss: 12.1680
# Epoch 133/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2614 - val_loss: 11.9727
# Epoch 134/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2721 - val_loss: 11.8494
# Epoch 135/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2535 - val_loss: 11.8806
# Epoch 136/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2408 - val_loss: 11.9531
# Epoch 137/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2573 - val_loss: 12.0030
# Epoch 138/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2710 - val_loss: 11.9475
# Epoch 139/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2473 - val_loss: 11.9993
# Epoch 140/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2524 - val_loss: 11.7502
# Epoch 141/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2447 - val_loss: 11.7894
# Epoch 142/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.2433 - val_loss: 11.9620
# Epoch 143/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2930 - val_loss: 12.1454
# Epoch 144/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2277 - val_loss: 11.8671
# Epoch 145/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2435 - val_loss: 11.7704
# Epoch 146/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2096 - val_loss: 11.8011
# Epoch 147/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1874 - val_loss: 11.9013
# Epoch 148/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.2125 - val_loss: 12.0027
# Epoch 149/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2060 - val_loss: 11.7538
# Epoch 150/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2065 - val_loss: 11.8552
# Epoch 151/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2044 - val_loss: 11.8186
# Epoch 152/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1942 - val_loss: 11.9042
# Epoch 153/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.1785 - val_loss: 11.7239
# Epoch 154/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2030 - val_loss: 11.9865
# Epoch 155/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2483 - val_loss: 11.6530
# Epoch 156/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1674 - val_loss: 11.9459
# Epoch 157/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1666 - val_loss: 11.9499
# Epoch 158/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1614 - val_loss: 11.8136
# Epoch 159/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1540 - val_loss: 11.8343
# Epoch 160/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1749 - val_loss: 11.6868
# Epoch 161/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.1493 - val_loss: 11.7474
# Epoch 162/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1456 - val_loss: 11.7236
# Epoch 163/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1589 - val_loss: 11.8256
# Epoch 164/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.1662 - val_loss: 12.0916
# Epoch 165/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1814 - val_loss: 11.7209
# Epoch 166/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1195 - val_loss: 11.7395
# Epoch 167/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1642 - val_loss: 11.9057
# Epoch 168/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1376 - val_loss: 11.6982
# Epoch 169/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1135 - val_loss: 11.6278
# Epoch 170/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1262 - val_loss: 11.7732
# Epoch 171/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1212 - val_loss: 11.6312
# Epoch 172/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1592 - val_loss: 11.8807
# Epoch 173/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.0966 - val_loss: 11.7704
# Epoch 174/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1353 - val_loss: 11.7697
# Epoch 175/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1025 - val_loss: 11.8284
# Epoch 176/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1270 - val_loss: 11.6030
# Epoch 177/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.0994 - val_loss: 11.8366
# Epoch 178/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1160 - val_loss: 11.8301
# Epoch 179/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2290 - val_loss: 12.0838
# Epoch 180/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.3656 - val_loss: 11.4249
# Epoch 181/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.1853 - val_loss: 11.9472
# Epoch 182/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1155 - val_loss: 11.8150
# Epoch 183/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.0929 - val_loss: 11.6304
# Epoch 184/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1083 - val_loss: 11.6320
# Epoch 185/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1131 - val_loss: 11.8387
# Epoch 186/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.0881 - val_loss: 11.7060
# Epoch 187/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.0915 - val_loss: 11.6942
# Epoch 188/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1421 - val_loss: 11.7063
# Epoch 189/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.0871 - val_loss: 11.7532
# Epoch 190/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.0857 - val_loss: 11.8280
# Epoch 191/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.0539 - val_loss: 11.6404
# Epoch 192/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.0965 - val_loss: 11.5232
# Epoch 193/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1466 - val_loss: 11.9889
# Epoch 194/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.0783 - val_loss: 11.6952
# Epoch 195/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.0729 - val_loss: 11.6380
# Epoch 196/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1062 - val_loss: 11.7630
# Epoch 197/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.0677 - val_loss: 11.7507
# Epoch 198/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.0618 - val_loss: 11.7588
# Epoch 199/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.0672 - val_loss: 11.7974
# Epoch 200/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.0266 - val_loss: 11.6044
# 1/1 [==============================] - 0s 25ms/step - loss: 11.8275
# Test Loss: 11.827498435974121
# 1/1 [==============================] - 0s 93ms/step

# %%
# In this block of code, the ratio will be categorized 

def categorize_ratio(heights, circumferences):
  ratio_height_circumferences = circumferences/heights
  if ratio >3 :
    categories.append("This tree has an EXCELLENT ratio")
  elif 2<= ratio <= 3:
    categories.append("This tree has an IDEAL ratio")
  else:
    categories.append("This tree has BAD ratio")
  return categories

# %%
# In this code, the new heights and circumferences will be inputed (option 1 of prediction)

new_heights = input("Berapa perkiraan tinggi pohonnya? ")
new_circumferences = input("Berapa keliling batang pohonnya? ")
new_heights = 24
new_circumferences = 77.0

def categorize_new_ratio(new_heights, new_circumferences):
    new_ratio_height_circumferences = new_circumferences / new_heights
    categories = []  # Define the 'categories' list
    if new_ratio_height_circumferences > 3:
        categories.append("This tree has an EXCELLENT ratio")
    elif 2 <= new_ratio_height_circumferences <= 3:
        categories.append("This tree has an IDEAL ratio")
    else:
        categories.append("This tree has a BAD ratio")
    return new_ratio_height_circumferences, categories

# This code aims to calculate mean and standard deviation of heights and circumferences
mean_heights = df['heights'].mean()
std_heights = df['heights'].std()
mean_circumferences = df['circumferences'].mean()
std_circumferences = df['circumferences'].std()

# Then, normalize new heights and circumferences
normalized_new_heights = (new_heights - mean_heights) / std_heights
normalized_new_circumferences = (new_circumferences - mean_circumferences) / std_circumferences

# Make predictions on the normalized data
prediction = trained_model.predict([[normalized_new_heights, normalized_new_circumferences]])[0]

# Categorize the new ratio
new_ratio_height_circumferences, categories = categorize_new_ratio(new_heights, new_circumferences)

print("Predicted age is:", prediction)
print("The ratio is:", new_ratio_height_circumferences)
print("Category of the ratio is:", categories)
# Out:
# Berapa perkiraan tinggi pohonnya? 24
# Berapa keliling batang pohonnya? 77
# 1/1 [==============================] - 0s 41ms/step
# Predicted age is: [48.607708]
# The ratio is: 3.2083333333333335
# Category of the ratio is: ['This tree has an EXCELLENT ratio']

# %%
# In this block of code, the status of the tree

if prediction > 50:
    if "This tree has an EXCELLENT ratio" in categories:
        decision = "Safe"
    else:
        decision = "You have to be careful"
else:
    if "This tree has an EXCELLENT ratio" or "This tree has an IDEAL ratio" in categories:
        decision = "Safe"
    else:
        decision = "You have to be careful"

# Print the predicted age and decision
print("Predicted age is:", prediction)
print("The ratio is:", new_ratio_height_circumferences)
print("Category of the ratio is:", categories)
print("Status is:", decision)
# Out:
# Predicted age is: [48.607708]
# The ratio is: 3.2083333333333335
# Category of the ratio is: ['This tree has an EXCELLENT ratio']
# Status is: Safe

# %%
# We will print the model summary
trained_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                192
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,417
# Trainable params: 4,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
# In this block of code, the branch condition will be assessed and paired with the desired message
# Branch condition can be divided into 3 which each has 2 choices

#1
branch_1 = input("Enter your choice (a or b): ")

a = "Ranting pohon menyebar secara merata"
b = "Ranting pohon menyebar tidak merata"

if branch_1 == "a":
  print("Pohon memiliki potensi tumbang yang rendah karena memiliki ranting yang menyebar secara merata")
elif branch_1 == "b":
  print("Pohon memiliki potensi tumbang yang tinggi karena memiliki ranting yang tidak menyebar secara merata")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk dilakukan pembenahan dengan cara pemangkasan ranting pohon yang overgrow")
else:
    print("Invalid choice")
# Out:
# Enter your choice (a or b): a
# Pohon memiliki potensi tumbang yang rendah karena memiliki ranting yang menyebar secara merata

# %%
#2
branch_2 = input("Enter your choice (c or d): ")

c = "Ranting terlihat sehat"
d = "Ranting terlihat stress/layu/sakit"

if branch_2 == "c":
  print("Pohon memiliki potensi tumbang yang rendah karena memiliki ranting yang sehat")
elif branch_2 == "d":
  print("Pohon memiliki potensi tumbang yang tinggi karena memiliki ranting yang stress/layu/sakit")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk dilakukan pembenahan dengan cara pemangkasan ranting pohon yang terindikasi stress/layu/sakit")
else:
    print("Invalid choice")
# Out:
# Enter your choice (c or d): d
# Pohon memiliki potensi tumbang yang tinggi karena memiliki ranting yang stress/layu/sakit
# Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk dilakukan pembenahan dengan cara pemangkasan ranting pohon yang terindikasi stress/layu/sakit

# %%
#3
branch_3 = input("Enter your choice (e or f): ")

e = "Tidak terdapat bekas luka pada ranting"
f = "Terdapat bekas luka pada ranting"

if branch_3 == "e":
  print("Pohon memiliki potensi tumbang yang rendah karena tidak memiliki bekas luka")
elif branch_3 == "f":
  print("Pohon memiliki potensi tumbang yang tinggi karena memiliki bekas luka")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk dilakukan pembenahan dengan cara pemangkasan ranting pohon yang memiliki bekas luka")
else:
    print("Invalid choice")
# Out:
# Enter your choice (e or f): f
# Pohon memiliki potensi tumbang yang tinggi karena memiliki bekas luka
# Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk dilakukan pembenahan dengan cara pemangkasan ranting pohon yang memiliki bekas luka

# %%
# In this block of code, the root condition will be assessed and paired with the desired message
# Root condition can be divided into 2 which each has 2 choices

#1
root_1 = input("Enter your choice (a or b): ")

a = "Akar pohon tidak terlalu terpapar ke permukaan tanah"
b = "Akar pohon terpapar ke permukaan tanah"

if root_1 == "a":
  print("Pohon memiliki potensi tumbang yang rendah karena akar tidak terlalu terpapar ke permukaan tanah")
elif root_1 == "b":
  print("Pohon memiliki potensi tumbang yang tinggi karena akar terlalu terpapar ke permukaan tanah")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk penambahan pelapisan mulsa atau perbaikan permukaan tanah")
else:
    print("Invalid choice")
# Out:
# Enter your choice (a or b): a
# Pohon memiliki potensi tumbang yang rendah karena akar tidak terlalu terpapar ke permukaan tanah

# %%
#2
root_2 = input("Enter your choice (c or d): ")

c = "Tidak terlihat akar busuk"
d = "Terlihat akar busuk"

if root_2 == "c":
  print("Pohon memiliki potensi tumbang yang rendah karena tidak terlihat akar busuk")
elif root_2 == "d":
  print("Pohon memiliki potensi tumbang yang tinggi karena terlihat akar busuk")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan pemotongan akar busuk agar tidak menjalar ke akar yang lain")
else:
    print("Invalid choice")
# Out:
# Enter your choice (c or d): d
# Pohon memiliki potensi tumbang yang tinggi karena terlihat akar busuk
# Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan pemotongan akar busuk agar tidak menjalar ke akar yang lain

# %%
# In this block of code, the surrounding environment will be assessed and paired with the desired message

sur_env = input("Enter your choice (a, b, c, d, or e): ")

a = "Hutan"
b = "Taman kota, ruang terbuka hijau, atau kebun binatang"
c = "Pantai"
d = "Tepi jalan raya"
e = "Pemukiman penduduk"

if sur_env == "a":
  print("Pohon ini berada di tempat yang aman untuk bertumbuh. Tetap berhati-hati")
elif sur_env == "b":
  print("Pohon ini berada di tempat yang aman untuk bertumbuh. Tetap berhati-hati")
elif sur_env == "c":
  print("Pohon ini berada di tempat yang aman untuk bertumbuh. Tetap berhati-hati")
elif sur_env == "d":
  print("Pohon ini berada di tempat yang aman untuk bertumbuh. Berhati-hatilah ketika berjalan atau berkendara di dekat pohon ini")
elif sur_env == "e":
  print("Pohon ini berada di tempat yang rawan untuk menyebabkan kerugian. Konsultasi lebih lanjut dengan dinas kehutanan.")
else:
    print("Invalid choice")
# Out:
# Enter your choice (a, b, c, d, or e): a
# Pohon ini berada di tempat yang aman untuk bertumbuh. Tetap berhati-hati
