# %% [markdown]
# ## **Capstone Project of Bangkit**
#
# Team C23-PC767

# %%
# The first thing to do is to import libraries

import os
import zipfile
import random
import shutil
import pandas as pd
import string
import numpy as np
from shutil import copyfile

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img
from keras.models import Sequential
from keras.layers import Dense

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# This code aims to import the file from /content/Monkey Pod Tree Dataset with the format of the file is excel
# The excel has been uploaded to this google colab workbook
file_path = "/content/Full Dataset.xlsx"

# This code aims to read the Excel file into a pandas DataFrame
df = pd.read_excel(file_path)

# %%
column_names = df.columns.tolist()
if 'heights' not in column_names or 'circumferences' not in column_names or 'ages' not in column_names:
    raise ValueError("Column names not found in the dataset.")

dataset_array = df.values

X = dataset_array[:, [column_names.index('heights'), column_names.index('circumferences')]]
y = dataset_array[:, column_names.index('ages')]

# %%
# In this block of code, the dataset will be converted to a numpy array

data = df.to_numpy()
print("Shape of the data array:", data.shape)
# Out:
# Shape of the data array: (358, 5)

# %%
data = pd.read_excel('/content/Full Dataset.xlsx')

#This code aims to generate the output of the dataset from the head 20  rows
data.head(5)
# Out:
#    heights  circumferences  ages    ratios  status
# 0       10               7    23  0.700000       1
# 1       10               7    23  0.700000       1
# 2       10               8    22  0.800000       1
# 3       10               8    25  0.800000       1
# 4       17              14    35  0.823529       1

# %%
#This code aims to generate the output of the dataset from the head 20  rows
data.tail(5)
# Out:
#      heights  circumferences  ages  ratios  status
# 353        6              30    20     5.0       0
# 354        5              26    23     5.2       0
# 355        5              27    23     5.4       0
# 356        5              29    23     5.8       0
# 357        5              30    22     6.0       0

# %%
# This block of code aims to normalize the data using StandardScaler

def normalize_data(df):
    heights = df['heights']
    circumferences = df['circumferences']
    ages = df['ages']

    scaler = StandardScaler()
    X = df[['heights', 'circumferences']]
    X_normalized = scaler.fit_transform(X)

    normalized_heights = X_normalized[:, 0]
    normalized_circumferences = X_normalized[:, 1]

    return normalized_heights, normalized_circumferences, scaler

# %%
# In this code, the data will be splitted

def split_dataset(df, test_size, dev_size):
    X = df[['heights', 'circumferences']]
    y = df['ages']

    # Process of spliting the dataset into train and test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

    # Process of spliting the dataset into dev and test
    X_dev, X_test, y_dev, y_test = train_test_split(X_test, y_test, test_size=dev_size, random_state=42)

    return X_train, X_test, X_dev, y_train, y_test, y_dev

# Then, call the function with our DataFrame and sizes for test and dev
test_size = 0.2
dev_size = 0.25 
X_train, X_test, X_dev, y_train, y_test, y_dev = split_dataset(df, test_size, dev_size)

# Last, print the shapes of the split datasets
print("Train set shapes:")
print(X_train.shape, y_train.shape)
print("Validation set shapes:")
print(X_dev.shape, y_dev.shape)
print("Test set shapes:")
print(X_test.shape, y_test.shape)
# Out:
# Train set shapes:
# (286, 2) (286,)
# Validation set shapes:
# (54, 2) (54,)
# Test set shapes:
# (18, 2) (18,)

# %%
# In this code, the model will be trained

def train_neural_network(X_train, y_train, X_val, y_val):
    # Scale the features using StandardScaler
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)

    # Then, create a neural network model using keras.layers
    model = keras.Sequential([
        keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dense(1)
    ])

    # Then, compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train the model
    history = model.fit(X_train_scaled, y_train, epochs=200, batch_size=32, validation_data=(X_val_scaled, y_val))

    model.save('LeafAge.h5')
    model.save_weights("LeafAge.weights.bin")


    return model, history

# Data preparation
X_train, X_test, X_dev, y_train, y_test, y_dev = split_dataset(df, test_size, dev_size)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_dev_scaled = scaler.transform(X_dev)

# Then, train the neural network
trained_model, history = train_neural_network(X_train_scaled, y_train, X_dev_scaled, y_dev)

# Then, evaluate the model on the test set
X_test_scaled = scaler.transform(X_test)
test_loss = trained_model.evaluate(X_test_scaled, y_test)
print("Test Loss:", test_loss)

# Make predictions on the test set
y_pred = trained_model.predict(X_test_scaled)

# Last, plot the loss curves
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 9/9 [==============================] - 1s 26ms/step - loss: 2002.1132 - val_loss: 1897.2411
# Epoch 2/200
# 9/9 [==============================] - 0s 9ms/step - loss: 1968.1079 - val_loss: 1862.1353
# Epoch 3/200
# 9/9 [==============================] - 0s 6ms/step - loss: 1928.5221 - val_loss: 1820.1296
# Epoch 4/200
# 9/9 [==============================] - 0s 10ms/step - loss: 1878.9637 - val_loss: 1764.6349
# Epoch 5/200
# 9/9 [==============================] - 0s 9ms/step - loss: 1813.4670 - val_loss: 1693.2228
# Epoch 6/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1729.2336 - val_loss: 1601.8959
# Epoch 7/200
# 9/9 [==============================] - 0s 9ms/step - loss: 1622.9148 - val_loss: 1488.4672
# Epoch 8/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1493.7264 - val_loss: 1351.3651
# Epoch 9/200
# 9/9 [==============================] - 0s 7ms/step - loss: 1339.4915 - val_loss: 1192.0657
# Epoch 10/200
# 9/9 [==============================] - 0s 8ms/step - loss: 1160.2957 - val_loss: 1017.2042
# Epoch 11/200
# 9/9 [==============================] - 0s 9ms/step - loss: 972.8264 - val_loss: 830.6851
# Epoch 12/200
# 9/9 [==============================] - 0s 7ms/step - loss: 777.5002 - val_loss: 646.0837
# Epoch 13/200
# 9/9 [==============================] - 0s 8ms/step - loss: 588.7246 - val_loss: 477.4688
# Epoch 14/200
# 9/9 [==============================] - 0s 9ms/step - loss: 423.1912 - val_loss: 336.6658
# Epoch 15/200
# 9/9 [==============================] - 0s 9ms/step - loss: 295.0349 - val_loss: 231.0495
# Epoch 16/200
# 9/9 [==============================] - 0s 10ms/step - loss: 204.9327 - val_loss: 162.7830
# Epoch 17/200
# 9/9 [==============================] - 0s 6ms/step - loss: 149.6434 - val_loss: 124.9203
# Epoch 18/200
# 9/9 [==============================] - 0s 9ms/step - loss: 120.2271 - val_loss: 104.6449
# Epoch 19/200
# 9/9 [==============================] - 0s 8ms/step - loss: 105.0408 - val_loss: 92.4592
# Epoch 20/200
# 9/9 [==============================] - 0s 7ms/step - loss: 94.8640 - val_loss: 84.1666
# Epoch 21/200
# 9/9 [==============================] - 0s 7ms/step - loss: 87.5666 - val_loss: 77.1667
# Epoch 22/200
# 9/9 [==============================] - 0s 6ms/step - loss: 81.1775 - val_loss: 71.6330
# Epoch 23/200
# 9/9 [==============================] - 0s 6ms/step - loss: 75.9487 - val_loss: 66.4899
# Epoch 24/200
# 9/9 [==============================] - 0s 6ms/step - loss: 71.2309 - val_loss: 62.9305
# Epoch 25/200
# 9/9 [==============================] - 0s 6ms/step - loss: 67.1088 - val_loss: 59.5293
# Epoch 26/200
# 9/9 [==============================] - 0s 8ms/step - loss: 63.4230 - val_loss: 56.5655
# Epoch 27/200
# 9/9 [==============================] - 0s 7ms/step - loss: 60.1062 - val_loss: 53.8268
# Epoch 28/200
# 9/9 [==============================] - 0s 8ms/step - loss: 57.0296 - val_loss: 50.7832
# Epoch 29/200
# 9/9 [==============================] - 0s 6ms/step - loss: 53.9229 - val_loss: 48.4124
# Epoch 30/200
# 9/9 [==============================] - 0s 7ms/step - loss: 51.2348 - val_loss: 46.2031
# Epoch 31/200
# 9/9 [==============================] - 0s 8ms/step - loss: 48.6204 - val_loss: 43.6930
# Epoch 32/200
# 9/9 [==============================] - 0s 6ms/step - loss: 46.1462 - val_loss: 41.3520
# Epoch 33/200
# 9/9 [==============================] - 0s 9ms/step - loss: 43.7528 - val_loss: 39.4145
# Epoch 34/200
# 9/9 [==============================] - 0s 6ms/step - loss: 41.5290 - val_loss: 37.4938
# Epoch 35/200
# 9/9 [==============================] - 0s 9ms/step - loss: 39.4095 - val_loss: 35.7403
# Epoch 36/200
# 9/9 [==============================] - 0s 6ms/step - loss: 37.4269 - val_loss: 33.9440
# Epoch 37/200
# 9/9 [==============================] - 0s 7ms/step - loss: 35.5537 - val_loss: 32.4096
# Epoch 38/200
# 9/9 [==============================] - 0s 9ms/step - loss: 33.8318 - val_loss: 30.8619
# Epoch 39/200
# 9/9 [==============================] - 0s 8ms/step - loss: 32.1935 - val_loss: 29.4361
# Epoch 40/200
# 9/9 [==============================] - 0s 6ms/step - loss: 30.6198 - val_loss: 28.0145
# Epoch 41/200
# 9/9 [==============================] - 0s 8ms/step - loss: 29.2508 - val_loss: 26.9645
# Epoch 42/200
# 9/9 [==============================] - 0s 6ms/step - loss: 27.8126 - val_loss: 25.8349
# Epoch 43/200
# 9/9 [==============================] - 0s 9ms/step - loss: 26.5686 - val_loss: 24.7809
# Epoch 44/200
# 9/9 [==============================] - 0s 9ms/step - loss: 25.3611 - val_loss: 23.6791
# Epoch 45/200
# 9/9 [==============================] - 0s 9ms/step - loss: 24.2999 - val_loss: 22.7695
# Epoch 46/200
# 9/9 [==============================] - 0s 7ms/step - loss: 23.2738 - val_loss: 21.8798
# Epoch 47/200
# 9/9 [==============================] - 0s 6ms/step - loss: 22.3421 - val_loss: 21.0651
# Epoch 48/200
# 9/9 [==============================] - 0s 8ms/step - loss: 21.4399 - val_loss: 20.3990
# Epoch 49/200
# 9/9 [==============================] - 0s 9ms/step - loss: 20.6042 - val_loss: 19.7796
# Epoch 50/200
# 9/9 [==============================] - 0s 6ms/step - loss: 19.9710 - val_loss: 19.2385
# Epoch 51/200
# 9/9 [==============================] - 0s 6ms/step - loss: 19.2010 - val_loss: 18.6373
# Epoch 52/200
# 9/9 [==============================] - 0s 6ms/step - loss: 18.5120 - val_loss: 18.1341
# Epoch 53/200
# 9/9 [==============================] - 0s 6ms/step - loss: 17.9713 - val_loss: 17.5311
# Epoch 54/200
# 9/9 [==============================] - 0s 7ms/step - loss: 17.3487 - val_loss: 17.1395
# Epoch 55/200
# 9/9 [==============================] - 0s 8ms/step - loss: 16.8082 - val_loss: 16.7542
# Epoch 56/200
# 9/9 [==============================] - 0s 6ms/step - loss: 16.3556 - val_loss: 16.3895
# Epoch 57/200
# 9/9 [==============================] - 0s 6ms/step - loss: 15.8510 - val_loss: 15.9425
# Epoch 58/200
# 9/9 [==============================] - 0s 6ms/step - loss: 15.4419 - val_loss: 15.5520
# Epoch 59/200
# 9/9 [==============================] - 0s 10ms/step - loss: 15.0419 - val_loss: 15.2574
# Epoch 60/200
# 9/9 [==============================] - 0s 6ms/step - loss: 14.6664 - val_loss: 15.0409
# Epoch 61/200
# 9/9 [==============================] - 0s 7ms/step - loss: 14.3214 - val_loss: 14.8528
# Epoch 62/200
# 9/9 [==============================] - 0s 6ms/step - loss: 13.9590 - val_loss: 14.4917
# Epoch 63/200
# 9/9 [==============================] - 0s 6ms/step - loss: 13.6730 - val_loss: 14.1856
# Epoch 64/200
# 9/9 [==============================] - 0s 7ms/step - loss: 13.3674 - val_loss: 14.0372
# Epoch 65/200
# 9/9 [==============================] - 0s 6ms/step - loss: 13.0967 - val_loss: 13.8844
# Epoch 66/200
# 9/9 [==============================] - 0s 8ms/step - loss: 12.7954 - val_loss: 13.7030
# Epoch 67/200
# 9/9 [==============================] - 0s 10ms/step - loss: 12.5566 - val_loss: 13.5065
# Epoch 68/200
# 9/9 [==============================] - 0s 8ms/step - loss: 12.3377 - val_loss: 13.3006
# Epoch 69/200
# 9/9 [==============================] - 0s 9ms/step - loss: 12.1078 - val_loss: 13.1557
# Epoch 70/200
# 9/9 [==============================] - 0s 6ms/step - loss: 11.9089 - val_loss: 13.0872
# Epoch 71/200
# 9/9 [==============================] - 0s 7ms/step - loss: 11.7138 - val_loss: 12.9466
# Epoch 72/200
# 9/9 [==============================] - 0s 7ms/step - loss: 11.5249 - val_loss: 12.7365
# Epoch 73/200
# 9/9 [==============================] - 0s 10ms/step - loss: 11.3580 - val_loss: 12.7109
# Epoch 74/200
# 9/9 [==============================] - 0s 9ms/step - loss: 11.1895 - val_loss: 12.5489
# Epoch 75/200
# 9/9 [==============================] - 0s 9ms/step - loss: 11.0356 - val_loss: 12.5561
# Epoch 76/200
# 9/9 [==============================] - 0s 9ms/step - loss: 10.8878 - val_loss: 12.5016
# Epoch 77/200
# 9/9 [==============================] - 0s 7ms/step - loss: 10.7406 - val_loss: 12.3320
# Epoch 78/200
# 9/9 [==============================] - 0s 6ms/step - loss: 10.6018 - val_loss: 12.2986
# Epoch 79/200
# 9/9 [==============================] - 0s 8ms/step - loss: 10.4868 - val_loss: 12.2089
# Epoch 80/200
# 9/9 [==============================] - 0s 8ms/step - loss: 10.3721 - val_loss: 12.1544
# Epoch 81/200
# 9/9 [==============================] - 0s 6ms/step - loss: 10.2406 - val_loss: 12.1047
# Epoch 82/200
# 9/9 [==============================] - 0s 8ms/step - loss: 10.1549 - val_loss: 11.9548
# Epoch 83/200
# 9/9 [==============================] - 0s 7ms/step - loss: 10.0261 - val_loss: 11.9658
# Epoch 84/200
# 9/9 [==============================] - 0s 7ms/step - loss: 9.9381 - val_loss: 11.9984
# Epoch 85/200
# 9/9 [==============================] - 0s 7ms/step - loss: 9.8205 - val_loss: 11.9795
# Epoch 86/200
# 9/9 [==============================] - 0s 6ms/step - loss: 9.7472 - val_loss: 11.9254
# Epoch 87/200
# 9/9 [==============================] - 0s 8ms/step - loss: 9.6829 - val_loss: 11.7556
# Epoch 88/200
# 9/9 [==============================] - 0s 9ms/step - loss: 9.5701 - val_loss: 11.7565
# Epoch 89/200
# 9/9 [==============================] - 0s 6ms/step - loss: 9.5086 - val_loss: 11.7644
# Epoch 90/200
# 9/9 [==============================] - 0s 7ms/step - loss: 9.4159 - val_loss: 11.7198
# Epoch 91/200
# 9/9 [==============================] - 0s 8ms/step - loss: 9.3401 - val_loss: 11.7740
# Epoch 92/200
# 9/9 [==============================] - 0s 11ms/step - loss: 9.2918 - val_loss: 11.7438
# Epoch 93/200
# 9/9 [==============================] - 0s 11ms/step - loss: 9.2303 - val_loss: 11.7391
# Epoch 94/200
# 9/9 [==============================] - 0s 8ms/step - loss: 9.1598 - val_loss: 11.6466
# Epoch 95/200
# 9/9 [==============================] - 0s 10ms/step - loss: 9.0911 - val_loss: 11.5936
# Epoch 96/200
# 9/9 [==============================] - 0s 13ms/step - loss: 9.0647 - val_loss: 11.6079
# Epoch 97/200
# 9/9 [==============================] - 0s 10ms/step - loss: 9.0124 - val_loss: 11.5686
# Epoch 98/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.9640 - val_loss: 11.7297
# Epoch 99/200
# 9/9 [==============================] - 0s 13ms/step - loss: 8.9100 - val_loss: 11.6613
# Epoch 100/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.8737 - val_loss: 11.6386
# Epoch 101/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.8536 - val_loss: 11.6316
# Epoch 102/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.8271 - val_loss: 11.5150
# Epoch 103/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.7977 - val_loss: 11.7273
# Epoch 104/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.7377 - val_loss: 11.6186
# Epoch 105/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.7223 - val_loss: 11.5336
# Epoch 106/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.6923 - val_loss: 11.5461
# Epoch 107/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.7080 - val_loss: 11.8270
# Epoch 108/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.6800 - val_loss: 11.7142
# Epoch 109/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.6288 - val_loss: 11.6205
# Epoch 110/200
# 9/9 [==============================] - 0s 12ms/step - loss: 8.6145 - val_loss: 11.5928
# Epoch 111/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.5791 - val_loss: 11.6418
# Epoch 112/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.5994 - val_loss: 11.8809
# Epoch 113/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.5519 - val_loss: 11.7358
# Epoch 114/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.5301 - val_loss: 11.5812
# Epoch 115/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.5663 - val_loss: 11.6959
# Epoch 116/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.5133 - val_loss: 11.7504
# Epoch 117/200
# 9/9 [==============================] - 0s 13ms/step - loss: 8.5048 - val_loss: 11.7069
# Epoch 118/200
# 9/9 [==============================] - 0s 12ms/step - loss: 8.5334 - val_loss: 11.5388
# Epoch 119/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.4683 - val_loss: 11.6642
# Epoch 120/200
# 9/9 [==============================] - 0s 14ms/step - loss: 8.4881 - val_loss: 11.9163
# Epoch 121/200
# 9/9 [==============================] - 0s 12ms/step - loss: 8.4696 - val_loss: 11.8323
# Epoch 122/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.4563 - val_loss: 11.7738
# Epoch 123/200
# 9/9 [==============================] - 0s 12ms/step - loss: 8.4385 - val_loss: 11.6779
# Epoch 124/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.4441 - val_loss: 11.6610
# Epoch 125/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.4384 - val_loss: 11.7661
# Epoch 126/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.4291 - val_loss: 11.6639
# Epoch 127/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.4608 - val_loss: 11.6440
# Epoch 128/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.4218 - val_loss: 11.9417
# Epoch 129/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.4385 - val_loss: 11.7784
# Epoch 130/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.4018 - val_loss: 11.8889
# Epoch 131/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3976 - val_loss: 11.7516
# Epoch 132/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.4056 - val_loss: 11.7640
# Epoch 133/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.3691 - val_loss: 11.8225
# Epoch 134/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3897 - val_loss: 11.6656
# Epoch 135/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3714 - val_loss: 11.7935
# Epoch 136/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.3751 - val_loss: 11.9485
# Epoch 137/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.3628 - val_loss: 11.7584
# Epoch 138/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3546 - val_loss: 11.8006
# Epoch 139/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.3902 - val_loss: 11.8609
# Epoch 140/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.3460 - val_loss: 11.7177
# Epoch 141/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.3551 - val_loss: 11.6840
# Epoch 142/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.3610 - val_loss: 11.8885
# Epoch 143/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.3462 - val_loss: 11.7592
# Epoch 144/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.3426 - val_loss: 11.7871
# Epoch 145/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.3226 - val_loss: 11.8883
# Epoch 146/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.3303 - val_loss: 11.7927
# Epoch 147/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.3193 - val_loss: 11.7803
# Epoch 148/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.3287 - val_loss: 11.6864
# Epoch 149/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3501 - val_loss: 11.9575
# Epoch 150/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.3166 - val_loss: 11.8197
# Epoch 151/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.3557 - val_loss: 11.8863
# Epoch 152/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2960 - val_loss: 11.6699
# Epoch 153/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.3012 - val_loss: 11.6755
# Epoch 154/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.3048 - val_loss: 11.8139
# Epoch 155/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2912 - val_loss: 11.7192
# Epoch 156/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2841 - val_loss: 11.7712
# Epoch 157/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2811 - val_loss: 11.7925
# Epoch 158/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2728 - val_loss: 11.8205
# Epoch 159/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.3606 - val_loss: 11.9666
# Epoch 160/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.2948 - val_loss: 11.5915
# Epoch 161/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.3002 - val_loss: 11.8015
# Epoch 162/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2853 - val_loss: 11.6963
# Epoch 163/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.3037 - val_loss: 11.8044
# Epoch 164/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2798 - val_loss: 11.7372
# Epoch 165/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2612 - val_loss: 11.7765
# Epoch 166/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.2752 - val_loss: 11.9136
# Epoch 167/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2519 - val_loss: 11.6892
# Epoch 168/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2918 - val_loss: 11.8447
# Epoch 169/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2631 - val_loss: 11.6448
# Epoch 170/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.2941 - val_loss: 11.9336
# Epoch 171/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2724 - val_loss: 11.5288
# Epoch 172/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2423 - val_loss: 11.5974
# Epoch 173/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2416 - val_loss: 11.7015
# Epoch 174/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.2550 - val_loss: 11.7312
# Epoch 175/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2982 - val_loss: 12.0938
# Epoch 176/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.2510 - val_loss: 11.6313
# Epoch 177/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2520 - val_loss: 11.7586
# Epoch 178/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2273 - val_loss: 11.7384
# Epoch 179/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2247 - val_loss: 11.7381
# Epoch 180/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2211 - val_loss: 11.5785
# Epoch 181/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.2434 - val_loss: 11.7428
# Epoch 182/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2633 - val_loss: 11.7612
# Epoch 183/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2252 - val_loss: 11.6610
# Epoch 184/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2541 - val_loss: 11.8724
# Epoch 185/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.2500 - val_loss: 11.8813
# Epoch 186/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.2221 - val_loss: 11.6735
# Epoch 187/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2364 - val_loss: 11.6445
# Epoch 188/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.2276 - val_loss: 11.5753
# Epoch 189/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2466 - val_loss: 11.6995
# Epoch 190/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1939 - val_loss: 11.7923
# Epoch 191/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.1962 - val_loss: 11.7513
# Epoch 192/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2043 - val_loss: 11.6959
# Epoch 193/200
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2093 - val_loss: 11.7395
# Epoch 194/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.1999 - val_loss: 11.6280
# Epoch 195/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2047 - val_loss: 11.6966
# Epoch 196/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2650 - val_loss: 11.9946
# Epoch 197/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.2133 - val_loss: 11.5856
# Epoch 198/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.2528 - val_loss: 11.5364
# Epoch 199/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.1780 - val_loss: 11.8395
# Epoch 200/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.2358 - val_loss: 11.8694
# 1/1 [==============================] - 0s 28ms/step - loss: 12.1476
# Test Loss: 12.147568702697754
# 1/1 [==============================] - 0s 98ms/step

# %%
# In this block of code, the ratio will be categorized 

def categorize_ratio(heights, circumferences):
  ratio_height_circumferences = circumferences/heights
  if ratio >3 :
    categories.append("This tree has an EXCELLENT ratio")
  elif 2<= ratio <= 3:
    categories.append("This tree has an IDEAL ratio")
  else:
    categories.append("This tree has BAD ratio")
  return categories

# %%
# In this code, the new heights and circumferences will be inputed (option 1 of prediction)

new_heights = input("Berapa perkiraan tinggi pohonnya? ")
new_circumferences = input("Berapa keliling batang pohonnya? ")
new_heights = 24
new_circumferences = 77.0

def categorize_new_ratio(new_heights, new_circumferences):
    new_ratio_height_circumferences = new_circumferences / new_heights
    categories = []  # Define the 'categories' list
    if new_ratio_height_circumferences > 3:
        categories.append("This tree has an EXCELLENT ratio")
    elif 2 <= new_ratio_height_circumferences <= 3:
        categories.append("This tree has an IDEAL ratio")
    else:
        categories.append("This tree has a BAD ratio")
    return new_ratio_height_circumferences, categories

# This code aims to calculate mean and standard deviation of heights and circumferences
mean_heights = df['heights'].mean()
std_heights = df['heights'].std()
mean_circumferences = df['circumferences'].mean()
std_circumferences = df['circumferences'].std()

# Then, normalize new heights and circumferences
normalized_new_heights = (new_heights - mean_heights) / std_heights
normalized_new_circumferences = (new_circumferences - mean_circumferences) / std_circumferences

# Make predictions on the normalized data
prediction = trained_model.predict([[normalized_new_heights, normalized_new_circumferences]])[0]

# Categorize the new ratio
new_ratio_height_circumferences, categories = categorize_new_ratio(new_heights, new_circumferences)

print("Predicted age is:", prediction)
print("The ratio is:", new_ratio_height_circumferences)
print("Category of the ratio is:", categories)
# Out:
# Berapa perkiraan tinggi pohonnya? 7
# Berapa keliling batang pohonnya? 24
# 1/1 [==============================] - 0s 65ms/step
# Predicted age is: [48.56265]
# The ratio is: 3.2083333333333335
# Category of the ratio is: ['This tree has an EXCELLENT ratio']

# %%
# In this block of code, the status of the tree

if prediction > 50:
    if "This tree has an EXCELLENT ratio" in categories:
        decision = "Safe"
    else:
        decision = "You have to be careful"
else:
    if "This tree has an EXCELLENT ratio" or "This tree has an IDEAL ratio" in categories:
        decision = "Safe"
    else:
        decision = "You have to be careful"

# Print the predicted age and decision
print("Predicted age is:", prediction)
print("The ratio is:", new_ratio_height_circumferences)
print("Category of the ratio is:", categories)
print("Status is:", decision)
# Out:
# Predicted age is: [48.56265]
# The ratio is: 3.2083333333333335
# Category of the ratio is: ['This tree has an EXCELLENT ratio']
# Status is: Safe

# %%
# We will print the model summary
trained_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                192
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,417
# Trainable params: 4,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
# In this block of code, the branch condition will be assessed and paired with the desired message
# Branch condition can be divided into 3 which each has 2 choices

#1
branch_1 = input("Enter your choice (a or b): ")

a = "Ranting pohon menyebar secara merata"
b = "Ranting pohon menyebar tidak merata"

if branch_1 == "a":
  print("Pohon memiliki potensi tumbang yang rendah karena memiliki ranting yang menyebar secara merata")
elif branch_1 == "b":
  print("Pohon memiliki potensi tumbang yang tinggi karena memiliki ranting yang tidak menyebar secara merata")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk dilakukan pembenahan dengan cara pemangkasan ranting pohon yang overgrow")
else:
    print("Invalid choice")
# Out:
# Enter your choice (a or b): a
# Pohon memiliki potensi tumbang yang rendah karena memiliki ranting yang menyebar secara merata

# %%
#2
branch_2 = input("Enter your choice (c or d): ")

c = "Ranting terlihat sehat"
d = "Ranting terlihat stress/layu/sakit"

if branch_2 == "c":
  print("Pohon memiliki potensi tumbang yang rendah karena memiliki ranting yang sehat")
elif branch_2 == "d":
  print("Pohon memiliki potensi tumbang yang tinggi karena memiliki ranting yang stress/layu/sakit")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk dilakukan pembenahan dengan cara pemangkasan ranting pohon yang terindikasi stress/layu/sakit")
else:
    print("Invalid choice")
# Out:
# Enter your choice (c or d): c
# Pohon memiliki potensi tumbang yang rendah karena memiliki ranting yang sehat

# %%
#3
branch_3 = input("Enter your choice (e or f): ")

e = "Tidak terdapat bekas luka pada ranting"
f = "Terdapat bekas luka pada ranting"

if branch_3 == "e":
  print("Pohon memiliki potensi tumbang yang rendah karena tidak memiliki bekas luka")
elif branch_3 == "f":
  print("Pohon memiliki potensi tumbang yang tinggi karena memiliki bekas luka")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk dilakukan pembenahan dengan cara pemangkasan ranting pohon yang memiliki bekas luka")
else:
    print("Invalid choice")
# Out:
# Enter your choice (e or f): f
# Pohon memiliki potensi tumbang yang tinggi karena memiliki bekas luka
# Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk dilakukan pembenahan dengan cara pemangkasan ranting pohon yang memiliki bekas luka

# %%
# In this block of code, the root condition will be assessed and paired with the desired message
# Root condition can be divided into 2 which each has 2 choices

#1
root_1 = input("Enter your choice (a or b): ")

a = "Akar pohon tidak terlalu terpapar ke permukaan tanah"
b = "Akar pohon terpapar ke permukaan tanah"

if root_1 == "a":
  print("Pohon memiliki potensi tumbang yang rendah karena akar tidak terlalu terpapar ke permukaan tanah")
elif root_1 == "b":
  print("Pohon memiliki potensi tumbang yang tinggi karena akar terlalu terpapar ke permukaan tanah")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk penambahan pelapisan mulsa atau perbaikan permukaan tanah")
else:
    print("Invalid choice")
# Out:
# Enter your choice (a or b): a
# Pohon memiliki potensi tumbang yang rendah karena akar tidak terlalu terpapar ke permukaan tanah

# %%
#2
root_2 = input("Enter your choice (c or d): ")

c = "Tidak terlihat akar busuk"
d = "Terlihat akar busuk"

if root_2 == "c":
  print("Pohon memiliki potensi tumbang yang rendah karena tidak terlihat akar busuk")
elif root_2 == "d":
  print("Pohon memiliki potensi tumbang yang tinggi karena terlihat akar busuk")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan pemotongan akar busuk agar tidak menjalar ke akar yang lain")
else:
    print("Invalid choice")
# Out:
# Enter your choice (c or d): d
# Pohon memiliki potensi tumbang yang tinggi karena terlihat akar busuk
# Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan pemotongan akar busuk agar tidak menjalar ke akar yang lain

# %%
# In this block of code, the surrounding environment will be assessed and paired with the desired message

sur_env = input("Enter your choice (a, b, c, d, or e): ")

a = "Hutan"
b = "Taman kota, ruang terbuka hijau, atau kebun binatang"
c = "Pantai"
d = "Tepi jalan raya"
e = "Pemukiman penduduk"

if sur_env == "a":
  print("Pohon ini berada di tempat yang aman untuk bertumbuh. Tetap berhati-hati")
elif sur_env == "b":
  print("Pohon ini berada di tempat yang aman untuk bertumbuh. Tetap berhati-hati")
elif sur_env == "c":
  print("Pohon ini berada di tempat yang aman untuk bertumbuh. Tetap berhati-hati")
elif sur_env == "d":
  print("Pohon ini berada di tempat yang aman untuk bertumbuh. Berhati-hatilah ketika berjalan atau berkendara di dekat pohon ini")
elif sur_env == "e":
  print("Pohon ini berada di tempat yang rawan untuk menyebabkan kerugian. Konsultasi lebih lanjut dengan dinas kehutanan.")
else:
    print("Invalid choice")
# Out:
# Enter your choice (a, b, c, d, or e): e
# Pohon ini berada di tempat yang rawan untuk menyebabkan kerugian. Konsultasi lebih lanjut dengan dinas kehutanan.
