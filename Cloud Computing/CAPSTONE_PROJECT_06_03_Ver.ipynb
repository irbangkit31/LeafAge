# %% [markdown]
# ## **Capstone Project of Bangkit**
#
# Team C23-PC767

# %%
# The first thing to do is to import libraries

import os
import zipfile
import random
import shutil
import pandas as pd
import string
import numpy as np
from shutil import copyfile

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img
from keras.models import Sequential
from keras.layers import Dense

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# This code aims to import the file from /content/Monkey Pod Tree Dataset with the format of the file is excel
# The excel has been uploaded to this google colab workbook
file_path = "/content/Full Dataset.xlsx"

# This code aims to read the Excel file into a pandas DataFrame
df = pd.read_excel(file_path)

# %%
column_names = df.columns.tolist()
if 'heights' not in column_names or 'circumferences' not in column_names or 'ages' not in column_names:
    raise ValueError("Column names not found in the dataset.")

dataset_array = df.values

X = dataset_array[:, [column_names.index('heights'), column_names.index('circumferences')]]
y = dataset_array[:, column_names.index('ages')]

# %%
# In this block of code, the dataset will be converted to a numpy array

data = df.to_numpy()
print("Shape of the data array:", data.shape)
# Out:
# Shape of the data array: (358, 5)

# %%
data = pd.read_excel('/content/Full Dataset.xlsx')

#This code aims to generate the output of the dataset from the head 20  rows
data.head(5)
# Out:
#    heights  circumferences  ages     Ratio  Status
# 0        8              28    20  3.500000       0
# 1        9              25    23  2.777778       0
# 2        6              30    20  5.000000       0
# 3        6              26    23  4.333333       0
# 4        5              29    23  5.800000       0

# %%
#This code aims to generate the output of the dataset from the head 20  rows
data.tail(5)
# Out:
#      heights  circumferences  ages     Ratio  Status
# 353       38              39    60  1.026316       1
# 354       33              33    62  1.000000       1
# 355       41              40    65  0.975610       1
# 356       38              35    62  0.921053       1
# 357       40              41    64  1.025000       1

# %%
# This block of code aims to normalize the data using StandardScaler

def normalize_data(df):
    heights = df['heights']
    circumferences = df['circumferences']
    ages = df['ages']

    scaler = StandardScaler()
    X = df[['heights', 'circumferences']]
    X_normalized = scaler.fit_transform(X)

    normalized_heights = X_normalized[:, 0]
    normalized_circumferences = X_normalized[:, 1]

    return normalized_heights, normalized_circumferences, scaler

# %%
# In this code, the data will be splitted

def split_dataset(df, test_size, dev_size):
    X = df[['heights', 'circumferences']]
    y = df['ages']

    # Process of spliting the dataset into train and test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

    # Process of spliting the dataset into dev and test
    X_dev, X_test, y_dev, y_test = train_test_split(X_test, y_test, test_size=dev_size, random_state=42)

    return X_train, X_test, X_dev, y_train, y_test, y_dev

# Then, call the function with our DataFrame and sizes for test and dev
test_size = 0.2
dev_size = 0.25 
X_train, X_test, X_dev, y_train, y_test, y_dev = split_dataset(df, test_size, dev_size)

# Last, print the shapes of the split datasets
print("Train set shapes:")
print(X_train.shape, y_train.shape)
print("Validation set shapes:")
print(X_dev.shape, y_dev.shape)
print("Test set shapes:")
print(X_test.shape, y_test.shape)
# Out:
# Train set shapes:
# (286, 2) (286,)
# Validation set shapes:
# (54, 2) (54,)
# Test set shapes:
# (18, 2) (18,)

# %%
# In this code, the model will be trained

def train_neural_network(X_train, y_train, X_val, y_val):
    # Scale the features using StandardScaler
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)

    # Then, create a neural network model using keras.layers
    model = keras.Sequential([
        keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dense(1)
    ])

    # Then, compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train the model
    history = model.fit(X_train_scaled, y_train, epochs=200, batch_size=32, validation_data=(X_val_scaled, y_val))

    model.save('LeafAge.h5')
    model.save_weights("LeafAge.weights.bin")


    return model, history

# Data preparation
X_train, X_test, X_dev, y_train, y_test, y_dev = split_dataset(df, test_size, dev_size)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_dev_scaled = scaler.transform(X_dev)

# Then, train the neural network
trained_model, history = train_neural_network(X_train_scaled, y_train, X_dev_scaled, y_dev)

# Then, evaluate the model on the test set
X_test_scaled = scaler.transform(X_test)
test_loss = trained_model.evaluate(X_test_scaled, y_test)
print("Test Loss:", test_loss)

# Make predictions on the test set
y_pred = trained_model.predict(X_test_scaled)

# Last, plot the loss curves
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 9/9 [==============================] - 2s 44ms/step - loss: 2012.3894 - val_loss: 1896.4667
# Epoch 2/200
# 9/9 [==============================] - 0s 10ms/step - loss: 1976.6219 - val_loss: 1862.0614
# Epoch 3/200
# 9/9 [==============================] - 0s 11ms/step - loss: 1935.8661 - val_loss: 1818.8326
# Epoch 4/200
# 9/9 [==============================] - 0s 10ms/step - loss: 1883.0577 - val_loss: 1762.5269
# Epoch 5/200
# 9/9 [==============================] - 0s 9ms/step - loss: 1813.6978 - val_loss: 1690.9172
# Epoch 6/200
# 9/9 [==============================] - 0s 23ms/step - loss: 1726.3387 - val_loss: 1601.5775
# Epoch 7/200
# 9/9 [==============================] - 0s 23ms/step - loss: 1619.6418 - val_loss: 1492.4250
# Epoch 8/200
# 9/9 [==============================] - 0s 17ms/step - loss: 1490.7748 - val_loss: 1362.6064
# Epoch 9/200
# 9/9 [==============================] - 0s 21ms/step - loss: 1339.8113 - val_loss: 1212.7649
# Epoch 10/200
# 9/9 [==============================] - 0s 21ms/step - loss: 1169.6556 - val_loss: 1045.7478
# Epoch 11/200
# 9/9 [==============================] - 0s 19ms/step - loss: 983.2810 - val_loss: 866.9902
# Epoch 12/200
# 9/9 [==============================] - 0s 18ms/step - loss: 787.7938 - val_loss: 685.9794
# Epoch 13/200
# 9/9 [==============================] - 0s 22ms/step - loss: 603.2484 - val_loss: 513.8231
# Epoch 14/200
# 9/9 [==============================] - 0s 14ms/step - loss: 435.2826 - val_loss: 366.1848
# Epoch 15/200
# 9/9 [==============================] - 0s 22ms/step - loss: 299.0728 - val_loss: 253.6318
# Epoch 16/200
# 9/9 [==============================] - 0s 10ms/step - loss: 205.3960 - val_loss: 175.0324
# Epoch 17/200
# 9/9 [==============================] - 0s 9ms/step - loss: 147.0169 - val_loss: 127.4460
# Epoch 18/200
# 9/9 [==============================] - 0s 13ms/step - loss: 115.3477 - val_loss: 101.5380
# Epoch 19/200
# 9/9 [==============================] - 0s 19ms/step - loss: 99.0421 - val_loss: 87.4391
# Epoch 20/200
# 9/9 [==============================] - 0s 9ms/step - loss: 88.0166 - val_loss: 80.4107
# Epoch 21/200
# 9/9 [==============================] - 0s 17ms/step - loss: 79.8873 - val_loss: 75.1749
# Epoch 22/200
# 9/9 [==============================] - 0s 14ms/step - loss: 73.7140 - val_loss: 71.8922
# Epoch 23/200
# 9/9 [==============================] - 0s 28ms/step - loss: 68.2356 - val_loss: 68.7862
# Epoch 24/200
# 9/9 [==============================] - 0s 10ms/step - loss: 63.7791 - val_loss: 65.2322
# Epoch 25/200
# 9/9 [==============================] - 0s 12ms/step - loss: 60.1468 - val_loss: 62.1577
# Epoch 26/200
# 9/9 [==============================] - 0s 10ms/step - loss: 56.7508 - val_loss: 59.0321
# Epoch 27/200
# 9/9 [==============================] - 0s 18ms/step - loss: 53.7405 - val_loss: 55.9199
# Epoch 28/200
# 9/9 [==============================] - 0s 11ms/step - loss: 50.8201 - val_loss: 52.7484
# Epoch 29/200
# 9/9 [==============================] - 0s 10ms/step - loss: 48.2707 - val_loss: 49.4193
# Epoch 30/200
# 9/9 [==============================] - 0s 15ms/step - loss: 45.5805 - val_loss: 46.9165
# Epoch 31/200
# 9/9 [==============================] - 0s 11ms/step - loss: 43.1764 - val_loss: 44.0002
# Epoch 32/200
# 9/9 [==============================] - 0s 9ms/step - loss: 40.8192 - val_loss: 41.5324
# Epoch 33/200
# 9/9 [==============================] - 0s 10ms/step - loss: 38.7819 - val_loss: 38.7266
# Epoch 34/200
# 9/9 [==============================] - 0s 10ms/step - loss: 36.7841 - val_loss: 36.5691
# Epoch 35/200
# 9/9 [==============================] - 0s 31ms/step - loss: 34.8409 - val_loss: 34.5194
# Epoch 36/200
# 9/9 [==============================] - 0s 21ms/step - loss: 33.1548 - val_loss: 32.4748
# Epoch 37/200
# 9/9 [==============================] - 0s 13ms/step - loss: 31.5230 - val_loss: 30.7503
# Epoch 38/200
# 9/9 [==============================] - 0s 11ms/step - loss: 30.0077 - val_loss: 28.9149
# Epoch 39/200
# 9/9 [==============================] - 0s 10ms/step - loss: 28.5410 - val_loss: 27.6267
# Epoch 40/200
# 9/9 [==============================] - 0s 8ms/step - loss: 27.2163 - val_loss: 26.2865
# Epoch 41/200
# 9/9 [==============================] - 0s 9ms/step - loss: 25.9730 - val_loss: 24.7292
# Epoch 42/200
# 9/9 [==============================] - 0s 10ms/step - loss: 24.7978 - val_loss: 23.4115
# Epoch 43/200
# 9/9 [==============================] - 0s 9ms/step - loss: 23.7410 - val_loss: 22.4446
# Epoch 44/200
# 9/9 [==============================] - 0s 13ms/step - loss: 22.6566 - val_loss: 21.2258
# Epoch 45/200
# 9/9 [==============================] - 0s 18ms/step - loss: 21.7367 - val_loss: 20.1090
# Epoch 46/200
# 9/9 [==============================] - 0s 11ms/step - loss: 20.8223 - val_loss: 19.2438
# Epoch 47/200
# 9/9 [==============================] - 0s 18ms/step - loss: 20.0395 - val_loss: 18.6104
# Epoch 48/200
# 9/9 [==============================] - 0s 11ms/step - loss: 19.2991 - val_loss: 17.9967
# Epoch 49/200
# 9/9 [==============================] - 0s 18ms/step - loss: 18.5428 - val_loss: 17.1417
# Epoch 50/200
# 9/9 [==============================] - 0s 12ms/step - loss: 17.9750 - val_loss: 16.5430
# Epoch 51/200
# 9/9 [==============================] - 0s 12ms/step - loss: 17.3421 - val_loss: 15.8818
# Epoch 52/200
# 9/9 [==============================] - 0s 15ms/step - loss: 16.8032 - val_loss: 15.5249
# Epoch 53/200
# 9/9 [==============================] - 0s 17ms/step - loss: 16.3078 - val_loss: 15.1278
# Epoch 54/200
# 9/9 [==============================] - 0s 10ms/step - loss: 15.7791 - val_loss: 14.5668
# Epoch 55/200
# 9/9 [==============================] - 0s 10ms/step - loss: 15.3598 - val_loss: 14.0248
# Epoch 56/200
# 9/9 [==============================] - 0s 8ms/step - loss: 14.9619 - val_loss: 13.6834
# Epoch 57/200
# 9/9 [==============================] - 0s 11ms/step - loss: 14.5401 - val_loss: 13.4458
# Epoch 58/200
# 9/9 [==============================] - 0s 11ms/step - loss: 14.1886 - val_loss: 13.1473
# Epoch 59/200
# 9/9 [==============================] - 0s 22ms/step - loss: 13.9109 - val_loss: 12.7958
# Epoch 60/200
# 9/9 [==============================] - 0s 17ms/step - loss: 13.5793 - val_loss: 12.6088
# Epoch 61/200
# 9/9 [==============================] - 0s 8ms/step - loss: 13.3053 - val_loss: 12.2497
# Epoch 62/200
# 9/9 [==============================] - 0s 10ms/step - loss: 13.0141 - val_loss: 12.1526
# Epoch 63/200
# 9/9 [==============================] - 0s 23ms/step - loss: 12.7936 - val_loss: 11.9861
# Epoch 64/200
# 9/9 [==============================] - 0s 8ms/step - loss: 12.6071 - val_loss: 11.6410
# Epoch 65/200
# 9/9 [==============================] - 0s 9ms/step - loss: 12.3454 - val_loss: 11.5110
# Epoch 66/200
# 9/9 [==============================] - 0s 18ms/step - loss: 12.1554 - val_loss: 11.5251
# Epoch 67/200
# 9/9 [==============================] - 0s 12ms/step - loss: 11.9481 - val_loss: 11.3752
# Epoch 68/200
# 9/9 [==============================] - 0s 15ms/step - loss: 11.7795 - val_loss: 11.0972
# Epoch 69/200
# 9/9 [==============================] - 0s 10ms/step - loss: 11.5747 - val_loss: 10.9455
# Epoch 70/200
# 9/9 [==============================] - 0s 12ms/step - loss: 11.4273 - val_loss: 10.8216
# Epoch 71/200
# 9/9 [==============================] - 0s 10ms/step - loss: 11.2775 - val_loss: 10.7165
# Epoch 72/200
# 9/9 [==============================] - 0s 10ms/step - loss: 11.1352 - val_loss: 10.6718
# Epoch 73/200
# 9/9 [==============================] - 0s 12ms/step - loss: 11.0003 - val_loss: 10.5697
# Epoch 74/200
# 9/9 [==============================] - 0s 15ms/step - loss: 10.8699 - val_loss: 10.5030
# Epoch 75/200
# 9/9 [==============================] - 0s 15ms/step - loss: 10.7553 - val_loss: 10.3172
# Epoch 76/200
# 9/9 [==============================] - 0s 17ms/step - loss: 10.6326 - val_loss: 10.2982
# Epoch 77/200
# 9/9 [==============================] - 0s 10ms/step - loss: 10.5708 - val_loss: 10.2597
# Epoch 78/200
# 9/9 [==============================] - 0s 16ms/step - loss: 10.4386 - val_loss: 10.2450
# Epoch 79/200
# 9/9 [==============================] - 0s 10ms/step - loss: 10.3907 - val_loss: 10.2620
# Epoch 80/200
# 9/9 [==============================] - 0s 7ms/step - loss: 10.2893 - val_loss: 10.1815
# Epoch 81/200
# 9/9 [==============================] - 0s 10ms/step - loss: 10.1801 - val_loss: 10.0353
# Epoch 82/200
# 9/9 [==============================] - 0s 9ms/step - loss: 10.1203 - val_loss: 9.9587
# Epoch 83/200
# 9/9 [==============================] - 0s 12ms/step - loss: 10.0444 - val_loss: 9.9685
# Epoch 84/200
# 9/9 [==============================] - 0s 15ms/step - loss: 9.9742 - val_loss: 9.9892
# Epoch 85/200
# 9/9 [==============================] - 0s 15ms/step - loss: 9.9663 - val_loss: 9.8932
# Epoch 86/200
# 9/9 [==============================] - 0s 13ms/step - loss: 9.8751 - val_loss: 9.9679
# Epoch 87/200
# 9/9 [==============================] - 0s 9ms/step - loss: 9.8084 - val_loss: 9.9288
# Epoch 88/200
# 9/9 [==============================] - 0s 20ms/step - loss: 9.7705 - val_loss: 9.9151
# Epoch 89/200
# 9/9 [==============================] - 0s 17ms/step - loss: 9.7059 - val_loss: 9.8436
# Epoch 90/200
# 9/9 [==============================] - 0s 10ms/step - loss: 9.7207 - val_loss: 9.8267
# Epoch 91/200
# 9/9 [==============================] - 0s 11ms/step - loss: 9.6155 - val_loss: 9.7891
# Epoch 92/200
# 9/9 [==============================] - 0s 13ms/step - loss: 9.5953 - val_loss: 9.8339
# Epoch 93/200
# 9/9 [==============================] - 0s 14ms/step - loss: 9.5513 - val_loss: 9.8007
# Epoch 94/200
# 9/9 [==============================] - 0s 11ms/step - loss: 9.5091 - val_loss: 9.6978
# Epoch 95/200
# 9/9 [==============================] - 0s 12ms/step - loss: 9.4969 - val_loss: 9.6824
# Epoch 96/200
# 9/9 [==============================] - 0s 16ms/step - loss: 9.4528 - val_loss: 9.7779
# Epoch 97/200
# 9/9 [==============================] - 0s 18ms/step - loss: 9.4114 - val_loss: 9.8120
# Epoch 98/200
# 9/9 [==============================] - 0s 21ms/step - loss: 9.3953 - val_loss: 9.7562
# Epoch 99/200
# 9/9 [==============================] - 0s 27ms/step - loss: 9.3932 - val_loss: 9.8172
# Epoch 100/200
# 9/9 [==============================] - 0s 21ms/step - loss: 9.3467 - val_loss: 9.6552
# Epoch 101/200
# 9/9 [==============================] - 0s 25ms/step - loss: 9.3094 - val_loss: 9.6704
# Epoch 102/200
# 9/9 [==============================] - 0s 19ms/step - loss: 9.2875 - val_loss: 9.7777
# Epoch 103/200
# 9/9 [==============================] - 0s 15ms/step - loss: 9.2650 - val_loss: 9.7899
# Epoch 104/200
# 9/9 [==============================] - 0s 25ms/step - loss: 9.2361 - val_loss: 9.7068
# Epoch 105/200
# 9/9 [==============================] - 0s 24ms/step - loss: 9.2233 - val_loss: 9.6881
# Epoch 106/200
# 9/9 [==============================] - 0s 21ms/step - loss: 9.1968 - val_loss: 9.7229
# Epoch 107/200
# 9/9 [==============================] - 0s 31ms/step - loss: 9.1815 - val_loss: 9.6774
# Epoch 108/200
# 9/9 [==============================] - 0s 24ms/step - loss: 9.1532 - val_loss: 9.6827
# Epoch 109/200
# 9/9 [==============================] - 0s 29ms/step - loss: 9.1544 - val_loss: 9.7267
# Epoch 110/200
# 9/9 [==============================] - 0s 25ms/step - loss: 9.1343 - val_loss: 9.7719
# Epoch 111/200
# 9/9 [==============================] - 0s 34ms/step - loss: 9.1424 - val_loss: 9.7215
# Epoch 112/200
# 9/9 [==============================] - 0s 30ms/step - loss: 9.1277 - val_loss: 9.7607
# Epoch 113/200
# 9/9 [==============================] - 0s 22ms/step - loss: 9.1018 - val_loss: 9.7432
# Epoch 114/200
# 9/9 [==============================] - 0s 29ms/step - loss: 9.0721 - val_loss: 9.6854
# Epoch 115/200
# 9/9 [==============================] - 0s 23ms/step - loss: 9.0944 - val_loss: 9.6250
# Epoch 116/200
# 9/9 [==============================] - 0s 31ms/step - loss: 9.0627 - val_loss: 9.6498
# Epoch 117/200
# 9/9 [==============================] - 0s 19ms/step - loss: 9.0589 - val_loss: 9.7925
# Epoch 118/200
# 9/9 [==============================] - 0s 22ms/step - loss: 9.0372 - val_loss: 9.7443
# Epoch 119/200
# 9/9 [==============================] - 0s 12ms/step - loss: 9.0566 - val_loss: 9.6550
# Epoch 120/200
# 9/9 [==============================] - 0s 12ms/step - loss: 9.0165 - val_loss: 9.7549
# Epoch 121/200
# 9/9 [==============================] - 0s 20ms/step - loss: 9.0081 - val_loss: 9.7306
# Epoch 122/200
# 9/9 [==============================] - 0s 18ms/step - loss: 8.9828 - val_loss: 9.6783
# Epoch 123/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.9694 - val_loss: 9.6757
# Epoch 124/200
# 9/9 [==============================] - 0s 14ms/step - loss: 9.0179 - val_loss: 9.7235
# Epoch 125/200
# 9/9 [==============================] - 0s 22ms/step - loss: 8.9483 - val_loss: 9.6291
# Epoch 126/200
# 9/9 [==============================] - 0s 41ms/step - loss: 8.9532 - val_loss: 9.6663
# Epoch 127/200
# 9/9 [==============================] - 0s 23ms/step - loss: 8.9494 - val_loss: 9.6410
# Epoch 128/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.9389 - val_loss: 9.7298
# Epoch 129/200
# 9/9 [==============================] - 0s 17ms/step - loss: 8.9515 - val_loss: 9.7864
# Epoch 130/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.9206 - val_loss: 9.6659
# Epoch 131/200
# 9/9 [==============================] - 0s 15ms/step - loss: 8.9308 - val_loss: 9.6961
# Epoch 132/200
# 9/9 [==============================] - 0s 27ms/step - loss: 8.8890 - val_loss: 9.6722
# Epoch 133/200
# 9/9 [==============================] - 0s 30ms/step - loss: 8.8954 - val_loss: 9.6915
# Epoch 134/200
# 9/9 [==============================] - 0s 31ms/step - loss: 8.8910 - val_loss: 9.6415
# Epoch 135/200
# 9/9 [==============================] - 0s 22ms/step - loss: 8.9061 - val_loss: 9.6361
# Epoch 136/200
# 9/9 [==============================] - 0s 30ms/step - loss: 8.8691 - val_loss: 9.6731
# Epoch 137/200
# 9/9 [==============================] - 0s 24ms/step - loss: 8.9161 - val_loss: 9.6664
# Epoch 138/200
# 9/9 [==============================] - 0s 35ms/step - loss: 8.8784 - val_loss: 9.7598
# Epoch 139/200
# 9/9 [==============================] - 0s 31ms/step - loss: 8.8662 - val_loss: 9.6529
# Epoch 140/200
# 9/9 [==============================] - 0s 31ms/step - loss: 8.8453 - val_loss: 9.6392
# Epoch 141/200
# 9/9 [==============================] - 0s 15ms/step - loss: 8.8323 - val_loss: 9.6082
# Epoch 142/200
# 9/9 [==============================] - 0s 20ms/step - loss: 8.8729 - val_loss: 9.6894
# Epoch 143/200
# 9/9 [==============================] - 0s 18ms/step - loss: 8.8286 - val_loss: 9.6417
# Epoch 144/200
# 9/9 [==============================] - 0s 14ms/step - loss: 8.8644 - val_loss: 9.5886
# Epoch 145/200
# 9/9 [==============================] - 0s 20ms/step - loss: 8.8314 - val_loss: 9.6131
# Epoch 146/200
# 9/9 [==============================] - 0s 17ms/step - loss: 8.8192 - val_loss: 9.6637
# Epoch 147/200
# 9/9 [==============================] - 0s 21ms/step - loss: 8.8295 - val_loss: 9.5331
# Epoch 148/200
# 9/9 [==============================] - 0s 17ms/step - loss: 8.7967 - val_loss: 9.6456
# Epoch 149/200
# 9/9 [==============================] - 0s 19ms/step - loss: 8.8057 - val_loss: 9.7095
# Epoch 150/200
# 9/9 [==============================] - 0s 23ms/step - loss: 8.7764 - val_loss: 9.5334
# Epoch 151/200
# 9/9 [==============================] - 0s 21ms/step - loss: 8.7844 - val_loss: 9.5435
# Epoch 152/200
# 9/9 [==============================] - 0s 16ms/step - loss: 8.7862 - val_loss: 9.6347
# Epoch 153/200
# 9/9 [==============================] - 0s 15ms/step - loss: 8.8547 - val_loss: 9.7864
# Epoch 154/200
# 9/9 [==============================] - 0s 21ms/step - loss: 8.7431 - val_loss: 9.5594
# Epoch 155/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.7491 - val_loss: 9.5550
# Epoch 156/200
# 9/9 [==============================] - 0s 16ms/step - loss: 8.7439 - val_loss: 9.5289
# Epoch 157/200
# 9/9 [==============================] - 0s 14ms/step - loss: 8.7604 - val_loss: 9.6509
# Epoch 158/200
# 9/9 [==============================] - 0s 16ms/step - loss: 8.7491 - val_loss: 9.6303
# Epoch 159/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.7427 - val_loss: 9.5382
# Epoch 160/200
# 9/9 [==============================] - 0s 21ms/step - loss: 8.7340 - val_loss: 9.5370
# Epoch 161/200
# 9/9 [==============================] - 0s 13ms/step - loss: 8.7716 - val_loss: 9.5852
# Epoch 162/200
# 9/9 [==============================] - 0s 8ms/step - loss: 8.7155 - val_loss: 9.5554
# Epoch 163/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.7075 - val_loss: 9.6142
# Epoch 164/200
# 9/9 [==============================] - 0s 24ms/step - loss: 8.7250 - val_loss: 9.6420
# Epoch 165/200
# 9/9 [==============================] - 0s 15ms/step - loss: 8.7185 - val_loss: 9.6478
# Epoch 166/200
# 9/9 [==============================] - 0s 16ms/step - loss: 8.6788 - val_loss: 9.5120
# Epoch 167/200
# 9/9 [==============================] - 0s 17ms/step - loss: 8.6767 - val_loss: 9.4883
# Epoch 168/200
# 9/9 [==============================] - 0s 13ms/step - loss: 8.7245 - val_loss: 9.5568
# Epoch 169/200
# 9/9 [==============================] - 0s 17ms/step - loss: 8.7502 - val_loss: 9.4422
# Epoch 170/200
# 9/9 [==============================] - 0s 14ms/step - loss: 8.7356 - val_loss: 9.6967
# Epoch 171/200
# 9/9 [==============================] - 0s 18ms/step - loss: 8.6820 - val_loss: 9.5844
# Epoch 172/200
# 9/9 [==============================] - 0s 24ms/step - loss: 8.7009 - val_loss: 9.5462
# Epoch 173/200
# 9/9 [==============================] - 0s 13ms/step - loss: 8.7129 - val_loss: 9.4503
# Epoch 174/200
# 9/9 [==============================] - 0s 10ms/step - loss: 8.6772 - val_loss: 9.5365
# Epoch 175/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.6817 - val_loss: 9.5554
# Epoch 176/200
# 9/9 [==============================] - 0s 28ms/step - loss: 8.9067 - val_loss: 9.7964
# Epoch 177/200
# 9/9 [==============================] - 0s 22ms/step - loss: 8.6816 - val_loss: 9.4646
# Epoch 178/200
# 9/9 [==============================] - 0s 18ms/step - loss: 8.6703 - val_loss: 9.4907
# Epoch 179/200
# 9/9 [==============================] - 0s 15ms/step - loss: 8.6490 - val_loss: 9.5632
# Epoch 180/200
# 9/9 [==============================] - 0s 34ms/step - loss: 8.7469 - val_loss: 9.6753
# Epoch 181/200
# 9/9 [==============================] - 0s 25ms/step - loss: 8.6916 - val_loss: 9.5033
# Epoch 182/200
# 9/9 [==============================] - 0s 23ms/step - loss: 8.6916 - val_loss: 9.5058
# Epoch 183/200
# 9/9 [==============================] - 0s 20ms/step - loss: 8.6412 - val_loss: 9.5173
# Epoch 184/200
# 9/9 [==============================] - 0s 16ms/step - loss: 8.6412 - val_loss: 9.5462
# Epoch 185/200
# 9/9 [==============================] - 0s 22ms/step - loss: 8.6966 - val_loss: 9.4350
# Epoch 186/200
# 9/9 [==============================] - 0s 20ms/step - loss: 8.6598 - val_loss: 9.4959
# Epoch 187/200
# 9/9 [==============================] - 0s 24ms/step - loss: 8.6575 - val_loss: 9.6457
# Epoch 188/200
# 9/9 [==============================] - 0s 23ms/step - loss: 8.6539 - val_loss: 9.5618
# Epoch 189/200
# 9/9 [==============================] - 0s 19ms/step - loss: 8.6182 - val_loss: 9.4751
# Epoch 190/200
# 9/9 [==============================] - 0s 22ms/step - loss: 8.6207 - val_loss: 9.5085
# Epoch 191/200
# 9/9 [==============================] - 0s 28ms/step - loss: 8.6262 - val_loss: 9.4734
# Epoch 192/200
# 9/9 [==============================] - 0s 23ms/step - loss: 8.6390 - val_loss: 9.5983
# Epoch 193/200
# 9/9 [==============================] - 0s 21ms/step - loss: 8.7112 - val_loss: 9.4269
# Epoch 194/200
# 9/9 [==============================] - 0s 32ms/step - loss: 8.6834 - val_loss: 9.5884
# Epoch 195/200
# 9/9 [==============================] - 0s 32ms/step - loss: 8.6086 - val_loss: 9.4867
# Epoch 196/200
# 9/9 [==============================] - 0s 30ms/step - loss: 8.6272 - val_loss: 9.4857
# Epoch 197/200
# 9/9 [==============================] - 0s 13ms/step - loss: 8.6204 - val_loss: 9.4684
# Epoch 198/200
# 9/9 [==============================] - 0s 11ms/step - loss: 8.6272 - val_loss: 9.5559
# Epoch 199/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.6693 - val_loss: 9.4266
# Epoch 200/200
# 9/9 [==============================] - 0s 7ms/step - loss: 8.6339 - val_loss: 9.5751
# 1/1 [==============================] - 0s 24ms/step - loss: 9.1040
# Test Loss: 9.104029655456543
# 1/1 [==============================] - 0s 85ms/step

# %%
# In this block of code, the ratio will be categorized 

def categorize_ratio(heights, circumferences):
  ratio_height_circumferences = circumferences/heights
  if ratio >3 :
    categories.append("This tree has an EXCELLENT ratio")
  elif 2<= ratio <= 3:
    categories.append("This tree has an IDEAL ratio")
  else:
    categories.append("This tree has BAD ratio")
  return categories

# %%
# In this code, the new heights and circumferences will be inputed (option 1 of prediction)

new_heights = input("Berapa perkiraan tinggi pohonnya? ")
new_circumferences = input("Berapa keliling batang pohonnya? ")
new_heights = 24
new_circumferences = 77.0

def categorize_new_ratio(new_heights, new_circumferences):
    new_ratio_height_circumferences = new_circumferences / new_heights
    categories = []  # Define the 'categories' list
    if new_ratio_height_circumferences > 3:
        categories.append("This tree has an EXCELLENT ratio")
    elif 2 <= new_ratio_height_circumferences <= 3:
        categories.append("This tree has an IDEAL ratio")
    else:
        categories.append("This tree has a BAD ratio")
    return new_ratio_height_circumferences, categories

# This code aims to calculate mean and standard deviation of heights and circumferences
mean_heights = df['heights'].mean()
std_heights = df['heights'].std()
mean_circumferences = df['circumferences'].mean()
std_circumferences = df['circumferences'].std()

# Then, normalize new heights and circumferences
normalized_new_heights = (new_heights - mean_heights) / std_heights
normalized_new_circumferences = (new_circumferences - mean_circumferences) / std_circumferences

# Make predictions on the normalized data
prediction = trained_model.predict([[normalized_new_heights, normalized_new_circumferences]])[0]

# Categorize the new ratio
new_ratio_height_circumferences, categories = categorize_new_ratio(new_heights, new_circumferences)

print("Predicted age is:", prediction)
print("The ratio is:", new_ratio_height_circumferences)
print("Category of the ratio is:", categories)
# Out:
# Berapa perkiraan tinggi pohonnya? 8
# Berapa keliling batang pohonnya? 28
# 1/1 [==============================] - 0s 43ms/step
# Predicted age is: [48.453636]
# The ratio is: 3.2083333333333335
# Category of the ratio is: ['This tree has an EXCELLENT ratio']

# %%
# In this block of code, the status of the tree

if prediction > 50:
    if "This tree has an EXCELLENT ratio" in categories:
        decision = "Safe"
    else:
        decision = "You have to be careful"
else:
    if "This tree has an EXCELLENT ratio" or "This tree has an IDEAL ratio" in categories:
        decision = "Safe"
    else:
        decision = "You have to be careful"

# Print the predicted age and decision
print("Predicted age is:", prediction)
print("The ratio is:", new_ratio_height_circumferences)
print("Category of the ratio is:", categories)
print("Status is:", decision)
# Out:
# Predicted age is: [48.453636]
# The ratio is: 3.2083333333333335
# Category of the ratio is: ['This tree has an EXCELLENT ratio']
# Status is: Safe

# %%
# We will print the model summary
trained_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                192
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,417
# Trainable params: 4,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
# In this block of code, the branch condition will be assessed and paired with the desired message
# Branch condition can be divided into 3 which each has 2 choices

#1
branch_1 = input("Enter your choice (a or b): ")

a = "Ranting pohon menyebar secara merata"
b = "Ranting pohon menyebar tidak merata"

if branch_1 == "a":
  print("Pohon memiliki potensi tumbang yang rendah karena memiliki ranting yang menyebar secara merata")
elif branch_1 == "b":
  print("Pohon memiliki potensi tumbang yang tinggi karena memiliki ranting yang tidak menyebar secara merata")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk dilakukan pembenahan dengan cara pemangkasan ranting pohon yang overgrow")
else:
    print("Invalid choice")
# Out:
# Enter your choice (a or b): a
# Pohon memiliki potensi tumbang yang rendah karena memiliki ranting yang menyebar secara merata

# %%
#2
branch_2 = input("Enter your choice (c or d): ")

c = "Ranting terlihat sehat"
d = "Ranting terlihat stress/layu/sakit"

if branch_2 == "c":
  print("Pohon memiliki potensi tumbang yang rendah karena memiliki ranting yang sehat")
elif branch_2 == "d":
  print("Pohon memiliki potensi tumbang yang tinggi karena memiliki ranting yang stress/layu/sakit")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk dilakukan pembenahan dengan cara pemangkasan ranting pohon yang terindikasi stress/layu/sakit")
else:
    print("Invalid choice")
# Out:
# Enter your choice (c or d): c
# Pohon memiliki potensi tumbang yang rendah karena memiliki ranting yang sehat

# %%
#3
branch_3 = input("Enter your choice (e or f): ")

e = "Tidak terdapat bekas luka pada ranting"
f = "Terdapat bekas luka pada ranting"

if branch_3 == "e":
  print("Pohon memiliki potensi tumbang yang rendah karena tidak memiliki bekas luka")
elif branch_3 == "f":
  print("Pohon memiliki potensi tumbang yang tinggi karena memiliki bekas luka")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk dilakukan pembenahan dengan cara pemangkasan ranting pohon yang memiliki bekas luka")
else:
    print("Invalid choice")
# Out:
# Enter your choice (e or f): e
# Pohon memiliki potensi tumbang yang rendah karena tidak memiliki bekas luka

# %%
# In this block of code, the root condition will be assessed and paired with the desired message
# Root condition can be divided into 2 which each has 2 choices

#1
root_1 = input("Enter your choice (a or b): ")

a = "Akar pohon tidak terlalu terpapar ke permukaan tanah"
b = "Akar pohon terpapar ke permukaan tanah"

if root_1 == "a":
  print("Pohon memiliki potensi tumbang yang rendah karena akar tidak terlalu terpapar ke permukaan tanah")
elif root_1 == "b":
  print("Pohon memiliki potensi tumbang yang tinggi karena akar terlalu terpapar ke permukaan tanah")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan untuk penambahan pelapisan mulsa atau perbaikan permukaan tanah")
else:
    print("Invalid choice")
# Out:
# Enter your choice (a or b): a
# Pohon memiliki potensi tumbang yang rendah karena akar tidak terlalu terpapar ke permukaan tanah

# %%
#2
root_2 = input("Enter your choice (c or d): ")

c = "Tidak terlihat akar busuk"
d = "Terlihat akar busuk"

if root_2 == "c":
  print("Pohon memiliki potensi tumbang yang rendah karena tidak terlihat akar busuk")
elif root_2 == "d":
  print("Pohon memiliki potensi tumbang yang tinggi karena terlihat akar busuk")
  print("Mohon hubungi pihak pemelihara kawasan untuk peninjauan lebih lanjut. Kami merekomendasikan pemotongan akar busuk agar tidak menjalar ke akar yang lain")
else:
    print("Invalid choice")
# Out:
# Enter your choice (c or d): c
# Pohon memiliki potensi tumbang yang rendah karena tidak terlihat akar busuk

# %%
# In this block of code, the surrounding environment will be assessed and paired with the desired message

sur_env = input("Enter your choice (a, b, c, d, or e): ")

a = "Hutan"
b = "Taman kota, ruang terbuka hijau, atau kebun binatang"
c = "Pantai"
d = "Tepi jalan raya"
e = "Pemukiman penduduk"

if sur_env == "a":
  print("Pohon ini berada di tempat yang aman untuk bertumbuh. Tetap berhati-hati")
elif sur_env == "b":
  print("Pohon ini berada di tempat yang aman untuk bertumbuh. Tetap berhati-hati")
elif sur_env == "c":
  print("Pohon ini berada di tempat yang aman untuk bertumbuh. Tetap berhati-hati")
elif sur_env == "d":
  print("Pohon ini berada di tempat yang aman untuk bertumbuh. Berhati-hatilah ketika berjalan atau berkendara di dekat pohon ini")
elif sur_env == "e":
  print("Pohon ini berada di tempat yang rawan untuk menyebabkan kerugian. Konsultasi lebih lanjut dengan dinas kehutanan.")
else:
    print("Invalid choice")
# Out:
# Enter your choice (a, b, c, d, or e): a
# Pohon ini berada di tempat yang aman untuk bertumbuh. Tetap berhati-hati
